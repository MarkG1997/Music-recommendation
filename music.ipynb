# %%
import os
import sys
import time
import glob
import datetime
import sqlite3
import numpy as np

# %%
# path to the Million Song Dataset subset (uncompressed)
# CHANGE IT TO YOUR LOCAL CONFIGURATION
msd_subset_path=r'A:\notebook\Notebook\Jupyter Notebooks\MillionSongSubset'
msd_subset_data_path=os.path.join(msd_subset_path,'data')
msd_subset_addf_path=os.path.join(msd_subset_path,'AdditionalFiles')

# %%
assert os.path.isdir(msd_subset_path),'wrong path' # sanity check

# %%
import hdf5_getters as GETTERS
def strtimedelta(starttime,stoptime):
    return str(datetime.timedelta(seconds=stoptime-starttime))

# %%
def apply_to_all_files(basedir,func=lambda x: x,ext='.h5'):
    """
    From a base directory, go through all subdirectories,
    find all files with the given extension, apply the
    given function 'func' to all of them.
    If no 'func' is passed, we do nothing except counting.
    INPUT
       basedir  - base directory of the dataset
       func     - function to apply to all filenames
       ext      - extension, .h5 by default
    RETURN
       number of files
    """
    cnt = 0
    # iterate over all files in all subdirectories
    for root, dirs, files in os.walk(basedir):
        files = glob.glob(os.path.join(root,'*'+ext))
        # count files
        cnt +=len(files)
        # apply function to all files
        for f in files :
            func(f)       
    return cnt

# we can now easily count the number of files in the dataset
print ('number of song files:',apply_to_all_files(msd_subset_data_path))

# let's now get all artist names in a set(). One nice property:
# if we enter many times the same artist, only one will be kept.
all_artist_names = set()

# we define the function to apply to all files
def func_to_get_artist_name(filename):
    """
    This function does 3 simple things:
    - open the song file
    - get artist ID and put it
    - close the file
    """
    h5 = GETTERS.open_h5_file_read(filename)
    artist_name = GETTERS.get_artist_name(h5)
    all_artist_names.add( artist_name )
    h5.close()
    
# let's apply the previous function to all files
# we'll also measure how long it takes
t1 = time.time()
apply_to_all_files(msd_subset_data_path,func=func_to_get_artist_name)
t2 = time.time()
print ('all artist names extracted in:',strtimedelta(t1,t2))

print(all_artist_names)
# Out:
# number of song files: 10000
# all artist names extracted in: 0:00:49.632030
# {b'The Field Mice', b'C.J. Chenier', b'Samy Deluxe', b'Phil Vassar', b'Bebe Winans', b'Doyle Bramhall', b'The Almost', b'Harry Connick_ Jr', b'Buddy Jewell', b'J.B.Lenoir', b'Ed Bruce', b'Leo Gandelman', b'Oui Oui', b'Cinder', b'Plagia', b'Refractory', b'Abijah', b'Incubus', b'Tum Tum / Double T / LiL Ronnie', b'P.o.d', b'Adam Richman', b'Steve Green', b'Wild Horses', b'Diamond D', b'Janina', b'Kisha', b'R. Carlos Nakai', b'Billy Butler', b'Leigh Jones', b'Sven Tasnadi', b'Eko Fresh feat. G-Style', b'Barbara Carr', b'D.A.R.', b'Autumnblaze', b'Albert Pr\xc3\xa9jean', b'Acorps de Rue', b'Ambient Music Therapy', b'Major Lazer', b'Bodies In the Gears of the Apparatus', b'Mira', b'Jacques Ferchit', b'Asha Puthli', b'Gal Costa / Maria Beth\xc3\xa2nia', b'For Squirrels', b'The Birds', b'Lily Allen Featuring Ours', b'Toby Love', b'Stimulator', b'The Irish Tenors', b'The Jane Shermans', b'Danielle Bollinger', b'Camp Lo', b'Clara Nunes', b'Miguel Migs', b'Bounty Killer', b'Hoodfellas', b'SUE THOMPSON', b'Nick Jonas & The Administration', b'David Arkenstone', b'Seamus Egan', b'30 Seconds To Mars', b'Kruger', b'Al Toomer', b'Richard Walters', b'Onesidezero', b'Eagles', b'Vin\xc3\xadcius de Moraes', b'3 Doors Down', b'Pat Metheny', b'Mister Ries', b'Cool Connection', b'A Tundra', b'Hinge', b'Shaggy / Brian & Tony Gold', b'Vincent Bruley', b'Montserrat Caball\xc3\xa9/Royal Philharmonic Orchestra/Lamberto Gardelli', b'DMX / Eve / Jadakiss', b'Kitty Kallen', b'Steve Smith', b'Torcuato Mariano', b'Frost', b'John Williams', b'Behemoth', b'BT feat. JES', b'Erik Berglund', b'Bone Thugs-N-Harmony / Akon', b'Bob Sinclar', b'From Dying Skies', b'M83', b'Catherine King/Matthew Schwinghammer/The American Boychoir', b'Francisco C\xc3\xa9spedes', b'Babe Ruth', b'Andr\xc3\xa9 Verchuren', b'Spooky Tooth', b'HA-ASH', b'Mich\xc3\xa8le Crider;Eleonora Jankovic;Vincenzo La Scola;Riccardo Muti', b'Carl Belew', b'Capone-N-Noreaga feat. Busta Rhymes and Ron Browz', b'Timo Maas', b'Janis Joplin', b'Gertrudis', b'Devo', b'Chet Atkins', b'Donnie McClurkin', b'Nicole C. Mullen', b'B.B. King', b'Frankie J', b'Lil Boosie feat. Bun B_ Trae_ Yo Gotti & Foxx', b'X', b'Grachan Moncur III', b'J. Peter Robinson', b'Faith Hill & Tim McGraw', b'Hound Dog Taylor and The Houserockers', b'Cliff Bruner', b'LL Cool J / Amil', b'Mustafa Sandal / G\xc3\xbclcan', b'T.G.Sheppard', b'Jeremy Fisher', b'Rocky Hill', b'John And The Bluesbreakers Mayall', b'Shaman', b'Tracy Byrd', b'Leon Lai', b'Pee Wee Crayton', b'Bitty McLean', b'Gathering', b'Descendents', b'Liquid Gang', b'Mest', b'Canis Dirus', b'Penguin Caf\xc3\xa9 Orchestra', b'Larry Graham & Graham Central Station', b'Cassius Clay', b'Claude Fran\xc3\xa7ois', b'Morgion', b'The Del McCoury Band', b'The Last', b'Bottom Of The Hudson', b'Wailing Souls', b'Nick Ingman', b'Jay Tee & Baby Bash', b'Michael Landau', b'Igor Stravinsky', b'Soul Embraced', b'Kyle Eastwood', b'Janet Paschal', b'Dilated Peoples Featuring Black Thought', b'Gary Morris', b'Sophie Tucker', b'Guy Forsyth', b'Damita Jo', b'Tim Hornsby', b'The Radio Dept.', b'Sonora Santanera', b'This Is Hell', b'Pink Floyd', b'The Creation', b'Big Dee Irwin', b'(hed) p.e.', b'Terminal 11 feat. b.b0Nd', b'Time Factory', b'H-Town', b'Lady May', b'Andra\xc3\xa9 Crouch & Solid Gospel', b'Lionel Richie', b'Passion', b'Legacy Five', b'Catherine Howe & Vo Fletcher', b'Eddie Henderson', b'Karen Peck & New River', b'Ada Jane', b'Rockabye Baby!', b'Susana Seivane', b'Hins Cheung', b'Groucho Marx', b'The Sterns', b'Sweet', b'Dead Prez', b'Lara & The Gumbo Lickers', b'Agnes', b'John Cephas & Phil Wiggins', b'Markscheider Kunst', b'Virtue', b'Maria Callas/Giuseppe di Stefano/Ettore Bastianini/Silvana Zanolli/Luisa Mandelli/Giuseppe Zampieri/Arturo La Porta/Antonio Zerbini/Silvio Maionica/Coro e Orchestra del Teatro alla Scala_ Milano/Carlo Maria Giulini', b'Kokane', b'Claudio', b'Intars Busulis', b'Esperanza Spalding / Leo Genovese', b'NG3', b'The White Stripes', b'Cedric Myton', b'Lisa Lynne', ...
